# %% [markdown]
# # Data Types in Python
# - Bool: True / False
# - int: 2,4,-7
# - float: 3.5,-4.3
# - string: " I am a Data Scientist "
# - time: Date/Time type

# %%
A=3
A
# Out:
# 3

# %%
b=5
b
# Out:
# 5

# %%
type(A)
# Out:
# int

# %%
type(4.2)
type(True)
# Out:
# bool

# %%
type(" I am a Data Scientist")
# Out:
# str

# %%
type("This is India's progress" )
# Out:
# str

# %%
import datetime

# %%
datetime.date.today()
# Out:
# datetime.date(2019, 12, 21)

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2019, 12, 21, 19, 45, 39, 614432)

# %%
from datetime import datetime, date

# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3

# %%
datetime.now()
# Out:
# datetime.datetime(2019, 12, 21, 19, 45, 42, 571601)

# %%
date.today()
# Out:
# datetime.date(2019, 12, 21)

# %%
datetime.ctime
# Out:
# <method 'ctime' of 'datetime.datetime' objects>

# %%
# Create a date.
my_bday= date(1993,8,11)
my_bday
# Out:
# datetime.date(1993, 8, 11)

# %%
print(date.today()-my_bday)
# Out:
# 9628 days, 0:00:00

# %%
day=date(1996,6,22)
day
print(date.today()-day)
# Out:
# 8576 days, 0:00:00

# %%
import datetime
# Time delta  = To add 100 days from today
hundredth_day=date.today()+datetime.timedelta(days=100)
hundredth_day
# Out:
# datetime.date(2020, 3, 30)

# %%
# Auto Typecasting
3+4.5
# Out:
# 7.5

# %%
# Forced Typecasting
3 + int(4.5)
# Out:
# 7

# %%
bool(18)
# Out:
# True

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int (bool(-18))
# Out:
# 1

# %%
4.5+5+bool(-8)+int('6')+3.5+True
# Out:
# 21.0

# %% [markdown]
# # Order of Conversion
# ## bool -> int -> float -> str

# %%
2 * 'Datamites'
# Out:
# 'DatamitesDatamites'

# %%
str(2)+ 'Datemites'
# Out:
# '2Datemites'

# %%
text="I am Data Scientist"
text
# Out:
# 'I am Data Scientist'

# %%
type(text)
# Out:
# str

# %%
# Index starts from Zero
text[5]  # [] Selector operator - Used to select part of the text.
# Out:
# 'D'

# %%
# Slicing Operation ':' , [start:stop:step]
text[5:12]
# Out:
# 'Data Sc'

# %%
# Step - It takes alternative characters
text[5:12:2]
# Out:
# 'Dt c'

# %%
text[5:]
# Out:
# 'Data Scientist'

# %%
text[5:-1]
# Out:
# 'Data Scientis'

# %%
len(text)
# Out:
# 19

# %% [markdown]
# # Math Operators

# %%
print(10 + 4) #Addition
print(10 - 4) #Subtractiob
print(10 * 4) #Multiplication
print(10 ** 4) # Exponential
print(10 / 4) # Divison
print(5 % 4) # Modulus
print( 10//4)  # Floor division
# Out:
# 14
# 6
# 40
# 10000
# 2.5
# 1
# 2

# %% [markdown]
# # Logical and Comparison Operators

# %%
print( 5>3)
print(5>=3)
print(5!=5)
print(5 == 5)
# Out:
# True
# True
# False
# True

# %%
print(5>3 and 6<3)
print( 5 >3 or 6<3)
# Out:
# False
# True

# %%
print(5 == int('5') )
# Out:
# True

# %%
False and -2.0
# Out:
# False

# %% [markdown]
# # Conditional Statements

# %%
x=2
if(x>0):
    print("This is a positive number")
    print("This if IF Block")
elif(x==0):
    print("This is ZERO")
else:
    print("This is a negative number")
    print("This is ELSE Block")
print("I am out of IF-ELSE Block")
# Out:
# This is a positive number
# This if IF Block
# I am out of IF-ELSE Block

# %% [markdown]
# # Lists
# - It is a heterogeneous and flexible data structure.
# - Python Lists are flexible and can hold completely heterogeneous data and can be appended efficiently.

# %%
a= [3,4.5, True, 'Datamites']
a
# Out:
# [3, 4.5, True, 'Datamites']

# %%
type(a)
# Out:
# list

# %%
a[3]
# Out:
# 'Datamites'

# %%
a[-1]
# Out:
# 'Datamites'

# %%
myfamily=['dad','mom','me']
myfamily
# Out:
# ['dad', 'mom', 'me']

# %%
flaucinaucinihilipilification=2
flaucinaucinihilipilification
# Out:
# 2

# %%
myfamily.append('wife')
myfamily
# Out:
# ['dad', 'mom', 'me', 'wife']

# %%
myfamily.extend(['son','brother'])
myfamily
# Out:
# ['dad', 'mom', 'me', 'wife', 'son', 'brother']

# %%
myfamily.remove('brother')
myfamily
# Out:
# ['dad', 'mom', 'me', 'wife', 'son']

# %%
myfamily.pop(4)
# Out:
# 'son'

# %%
myfamily
# Out:
# ['dad', 'mom', 'me', 'wife']

# %%
myfamily.sort(reverse=True)
myfamily
# Out:
# ['wife', 'mom', 'me', 'dad']

# %%
myfamily.count('wife')
# Out:
# 1

# %%
myfamily[0:2]
# Out:
# ['wife', 'mom']

# %%
myfamily.remove('bro')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-6393182a7523> in <module>
# ----> 1 myfamily.remove('bro')
#
# ValueError: list.remove(x): x not in list

# %%
myfamily.insert(0,'grandfather')

# %%
myfamily
# Out:
# ['grandfather', 'wife', 'mom', 'me', 'dad']

# %% [markdown]
# # Tuples
# - Immutable , eg. Call logs
# - Put in normal paranthesis ( )

# %%
a=tuple([3,4,5])
print(a)
type(a)
# Out:
# (3, 4, 5)
# tuple

# %%
a.append()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-118-345ac4668da7> in <module>
# ----> 1 a.append()
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# # Dictionary
# - Python Dictionary is an unordered collection of items.
# - A dictionary has a key:value pair.
# - Dictionary are optimized to retrieve values when the key is known.

# %%
b=dict(name='Shahid', job='Data Scientist',age=25)
b
# Out:
# {'name': 'Shahid', 'job': 'Data Scientist', 'age': 25}

# %%
b['age']
# Out:
# 25

# %%
b['name']
# Out:
# 'Shahid'

# %%
b.keys()
# Out:
# dict_keys(['name', 'job', 'age'])

# %%
b.items()
# Out:
# dict_items([('name', 'Shahid'), ('job', 'Data Scientist'), ('age', 25)])

# %% [markdown]
# # Sets
# - A set contains an unordered collection of unique and immutable objects.

# %%
lang=set(['Java','C','Python'])
snakes=set(['Cobra','Anaconda','Python'])
type(lang)
# Out:
# set

# %%
lang.union(snakes)
# Out:
# {'Anaconda', 'C', 'Cobra', 'Java', 'Python'}

# %%
lang.intersection(snakes)
# Out:
# {'Python'}

# %%
lang.difference(snakes)
# Out:
# {'C', 'Java'}

# %% [markdown]
# # Creating Function

# %%
# BMI = Weight(kg) / height squared

# %%
def bmi(h,w):
    bmi=w/h**2
    print('Your BMI = ', bmi)

# %%
bmi(1.72,68)
# Out:
# Your BMI =  22.985397512168742

# %%
bmi(1.69,64)
# Out:
# Your BMI =  22.40817898532965

# %%
#Create a function for area of triangle
def areaoftriangle(b,h):
    areaoftriangle=(b*h)/2
    print('Area of Triangle = ',areaoftriangle)

# %%
areaoftriangle(3,3)
# Out:
# Area of Triangle =  4.5

# %% [markdown]
# # For Loop

# %%
fruits =(['Guava','Cherry','Mango','Apple'])
fruits
# Out:
# ['Guava', 'Cherry', 'Mango', 'Apple']

# %%
for f in fruits:
    print(f)
# Out:
# Guava
# Cherry
# Mango
# Apple

# %%
for f in fruits:
    if(f=='Cherry'):
        print('Hi Cherry')
        print(f)
# Out:
# Hi Cherry
# Cherry

# %%
for x in range(1,10):
    print(x,end=' ')
# Out:
# 1 2 3 4 5 6 7 8 9
